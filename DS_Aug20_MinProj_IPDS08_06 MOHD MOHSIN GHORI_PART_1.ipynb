# %%
#In oder to implement the dataFrames in the EDA
#In order to implement the array series of numbers concept in EDA #In order to implement the array series of numbers concept in EDA
#In order to draw the Insights between to different cont. values of EDA Dataset
#In order to draw plot,draw different graphs to show insights
import pandas as pd                 
import numpy as np                   
import matplotlib.pyplot as plt       
# %matplotlib inline
import seaborn as sns

# %%
eda1= pd.read_csv(r'C:\Users\Mohsin\TITANIC.csv') #since we are assigning a variable in order to read the csv file
eda1.head(10)                                      #In order to display the dataframe of the CSV file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d25ff1128af2> in <module>
# ----> 1 eda1= pd.read_csv(r'C:\Users\Mohsin\TITANIC.csv') #since we are assigning a variable in order to read the csv file
#       2 eda1.head(10)                                      #In order to display the dataframe of the CSV file
#
# NameError: name 'pd' is not defined

# %%
eda1.info()             #info() help to determine the data types of the Dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
eda1.describe()     #describe() function helps us to determine statistical features like means,standard deviation,max and min value
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.countplot(x='Sex',data=eda1) #In this countplot() function is used to determine the insights of Sex column

# %%
sns.countplot(x='Survived',data=eda1) #In this countplot() function is used to determine the insights of Survived column

# %%
sns.boxplot(y='Age',data=eda1)

# %%
sns.boxplot(y='Fare',data=eda1)

# %%
sns.distplot(eda1['SibSp'],bins=4)

# %%
sns.boxplot(y='Pclass',data=eda1)

# %%
sns.distplot(eda1['Pclass'],bins=4)

# %%
plt.scatter(eda1['Age'], eda1['Sex']) #By the help of Matplotlib.pyplot library we can draw insights btwn two different columns of the given dataset
plt.title('Age VS Sex')               #In this Scatter() function is been use to draw the differential Insights btwn AGE and SEX
plt.xlabel('Age')
plt.ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')

# %%
plt.scatter(eda1['Age'],eda1['Survived'])  #In this Scatter() function is been use to draw the differential Insights btwn AGE and SURVIVED
plt.title('Survived VS Age')               #Title() function is been used to give the title to the graph frames
plt.xlabel('Age')                          #xlabel() is to label the x-axis side column
plt.ylabel('Survived')                     #ylabel() is to label the y-axis side column
# Out:
# Text(0, 0.5, 'Survived')

# %%
eda_cont = eda1.iloc[:,:-3]
eda_cont
sns.pairplot(eda_cont)

# %%
eda1.isnull()   #In order to check the Null values of the dataset
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
eda1.isnull().values.any() #In order to remove the null values
# Out:
# True

# %%
eda1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
eda1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
eda1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
eda1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
eda1.hist(column=['Age'],bins=5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AE90F35B80>]],
#       dtype=object)

# %%
eda1['Age']=eda1['Age'].fillna(value=eda1['Age'].median())

# %%
eda1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
eda1.boxplot(column = ['Survived'])

# %%
plt.scatter(eda1['Survived'], eda1['Age'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
transformation = pd.read_csv(r'C:\Users\Mohsin\TITANIC.csv')
plt.scatter(transformation['Survived'], transformation['Age'])

# %%
transformation['Age']= np.log(transformation['Age'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-587b27e104ca> in <module>
# ----> 1 transformation['Age']= np.log(transformation['Age'])
#
# NameError: name 'np' is not defined
